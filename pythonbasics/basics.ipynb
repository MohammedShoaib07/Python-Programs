# %%
## STRING AND STRING CONCATINATION

name= "shoaib"
place= "ballari"
age= 19
marks= 100
value= 1


print(name,place)
print(name+str(age)+str(marks)+str(value))
print(name,age,end="this will be added at end of print")
print(name ,age ,marks ,value ,sep="@")
# Out:
# shoaib ballari
# shoaib191001
# shoaib 19this will be added at end of printshoaib@19@100@1

# %%
##write a program to print details and also in paragraph form

name= "shoaib"
age = 19
marks = 80.9

print(f"This is My Information:\n1)Name : {name}\n2)Age : {age}\n3)Marks : {marks}\nMy name is {name} and my age is {age} and, i got {marks} in my semester")
# Out:
# This is My Information:
# 1)Name : shoaib
# 2)Age : 19
# 3)Marks : 80.9
# My name is shoaib and my age is 19 and, i got 80.9 in my semester

# %%
## TAKING INPUT FROM USER AND PRINTING DETAILS

name=str(input("Enter name : "))
age=int(input("Enter age : "))
cgpa=float(input("Enter cgpa : "))

print("STUDENT DETAILS \n")

print("Name :",name)
print("age :",age)
print("cgpa :",cgpa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       1 ## TAKING INPUT FROM USER AND PRINTING DETAILS
#       3 name=str(input("Enter name : "))
# ----> 4 age=int(input("Enter age : "))
#       5 cgpa=float(input("Enter cgpa : "))
#       7 print("STUDENT DETAILS \n")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
## ARTHMETIC OPERATORS

a=10
b=20

print("sum of a and b is:",a+b)
print("difference of a and b is:",a-b)
print("product of a and b is:",a*b)
print("division of a and b is:",a/b)
print("floor division of a and b is:",a//b)
print("modulus of a and b is:",a%b)
print("a to the power of b is:",a**b)
# Out:
# sum of a and b is: 30
# difference of a and b is: -10
# product of a and b is: 200
# division of a and b is: 0.5
# floor division of a and b is: 0
# modulus of a and b is: 10
# a to the power of b is: 100000000000000000000

# %%
## ASSIGNMENT OPERATOR

a=10
b=20
b +=a
print(b)
# Out:
# 30
