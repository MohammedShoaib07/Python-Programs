# %%
t=(1,2,3,3,2,5,1,3,4,3,2)
print(type(t))
print(t)
c=t.count(3)
print("count of 3 is :",)
# Out:
# <class 'tuple'>
# (1, 2, 3, 3, 2, 5, 1, 3, 4, 3, 2)
# count of 3 is :

# %%
a=1,2,3
print(a)
# Out:
# (1, 2, 3)

# %%
t=(1,2,3)
print(t)
lst=list(t)
lst[0]=100
t=tuple(lst)
print(t)
# Out:
# (1, 2, 3)
# (100, 2, 3)

# %%
methods = dir(tuple)
for i in methods:
    print(i)
