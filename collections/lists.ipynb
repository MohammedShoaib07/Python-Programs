# %%
## LISTS BASICS

a =[1,5.9, "shoaib",True]
s = "shoaib"
l_s = list(s)
print(l_s)
print(type(a))

sentance = "hi my name is shoaib"

u_sentance =0
print(a)
u_sentance = sentance.split(" ")
print(u_sentance)
# Out:
# ['s', 'h', 'o', 'a', 'i', 'b']
# <class 'list'>
# [1, 5.9, 'shoaib', True]
# ['hi', 'my', 'name', 'is', 'shoaib']

# %%
## LISTS BASICS

lst=[1,1.5,"shoaib",True]


#append
lst.append("hey this is updated")
print(lst)
lst.append([1,2,3])
print(lst)
print(lst[5][2])

#extend
lst2=[1,2,3]
lst2.extend([4,5,6])
print(lst2)
# Out:
# using append
#
# [1, 1.5, 'shoaib', True]
# [1, 1.5, 'shoaib', True, 'hey this is updated']
# [1, 1.5, 'shoaib', True, 'hey this is updated', [1, 2, 3]]
# 3
#
# using extend
#
# [1, 2, 3, 4, 5, 6]

# %%
## LISTS BASICS

#update

lst=[1,2,3,4]
lst1=[1,2,3,4]
print(lst)

lst[0]=10
print(lst)

for i in range(len(lst)):
    lst[i]=lst[i]*lst[i]
print(lst)

u_l=[i*i for i in lst1]
print(u_l)
# Out:
# [1, 2, 3, 4]
# [10, 2, 3, 4]
# [100, 4, 9, 16]
# [1, 4, 9, 16]

# %%
## LISTS BASICS

#deleting of ele's

lst=[1,"shoaib",3,4,5,6]
lst.pop(0)
print(lst)

lst.remove("shoiab")
print(lst)
