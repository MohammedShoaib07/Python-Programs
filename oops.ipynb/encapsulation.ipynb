# %%
class Demo:

    def __init__(self):
        self.__name=""
        self.__password=""
        self.__age=0
    
    def set_name(self,n):
        self.__name=n

    def get_name(self):
        return self.__name
    
    def set_password(self,p):
        self.__password=p

    def get_password(self):
        return self.__password

    def s_age(self,a):
        if a <= 0:
            print("invalid age")
        else:
            self.__age=a

    def g_age(self):
        return self.__age


class Main:
    @staticmethod
    def main():
        obj=Demo()
        obj.set_name("shoaib")
        obj.set_password("shoaib@123")
        obj
