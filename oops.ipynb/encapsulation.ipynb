# %%
class Demo:

    def __init__(self):
        self.__name=""
        self.__password=""
        self.__age=0
    
    def set_name(self,n):
        self.__name=n

    def get_name(self):
        return self.__name
    
    def set_password(self,p):
        self.__password=p

    def get_password(self):
        return self.__password

    def s_age(self,a):
        if a <= 0:
            print("invalid age")
        else:
            self.__age=a

    def g_age(self):
        return self.__age


class Main:
    @staticmethod
    def main():
        obj=Demo()
        obj.set_name("shoaib")
        obj.set_password("shoaib@123")
        obj

# %%
class  CricketPlayer:

    def __init__(self):
        self.__name=""
        self.__totalRuns=0
        self.__matchesPlayed=0
    
    def set_name(self,n):
        self.__name=n
        
    def set_totalRuns(self,tr):
        if self.__totalRuns<0:
            print("INVALID VALUE")
        else:
            self.__totalRuns=tr
            
    def set_matchesPlayed(self,mp):
        if self.__matchesPlayed<0:
            print("INVALID VALUE")
        else:
            self.__matchesPlated=mp
            
    def get_name(self):
        return self.__name
            
    def get_totalRuns(self):
        return self.__totalRuns
    
    def get_matchesPlayed(self):
        return self.__matchesPlayed
    
class Main:
    @staticmethod
    def main():
        obj=demo()
        obj.set_name(input())
        obj.set_totalRuns(input())
        obj.set_matchesPlayed(input())
        
        def displaydetails():
            print("Cricket Player Details:\n")
            print(f"Name: {demo.get_name}")
            print(f"Total Runs: {demo.get_totalRuns}")
            print(f"Matches Played: {demo.get_matchesPlayed}")
            
displaydetails()
Main.main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 46
#      43             print(f"Total Runs: {demo.get_totalRuns}")
#      44             print(f"Matches Played: {demo.get_matchesPlayed}")
# ---> 46 displaydetails()
#      47 Main.main()
#
# NameError: name 'displaydetails' is not defined
